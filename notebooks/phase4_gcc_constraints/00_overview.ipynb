# %% [markdown]
# # Phase 4: GCC Constraint Simulation
#
# ## Scope
# Simulate GCC constraints using toxiproxy: 200ms added latency, egress proxy,
# 60k TPM rate cap. Re-run the same four failures from Phase 3 and record which
# become unrecoverable.
#
# ## Where to start
# 1. Enable toxiproxy: `docker compose --profile gcc-sim up -d`
# 2. Configure `OPENAI_BASE_URL` to route through toxiproxy
# 3. Re-run Phase 3 failure suite with GCC constraints active
# 4. Compare recovery scores vs Phase 3 baseline
#
# ## Handoff requirement
# Document which failures become unrecoverable under GCC constraints.

# %%
# Phase 4 intern: implement this cell
# See docker-compose.yml (gcc-sim profile) for toxiproxy setup
raise NotImplementedError("Phase 4 not yet implemented")
