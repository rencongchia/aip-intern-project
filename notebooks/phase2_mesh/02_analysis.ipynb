# %% [markdown]
# # Phase 2 Mesh — Analysis

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path("../../")))

from analysis.aggregate import load_runs
from analysis.compare import compare_phases
from analysis.plots import plot_latency_distribution, plot_phase_comparison, plot_token_cost

baseline_df = load_runs("../../artifacts/", prefix="baseline")
mesh_df = load_runs("../../artifacts/", prefix="mesh")
print(f"Loaded {len(baseline_df)} baseline runs, {len(mesh_df)} mesh runs")
# Out:
# Loaded 20 baseline runs, 20 mesh runs

# %%
summary = compare_phases(baseline_df, mesh_df)
display(summary)
# Out:
#                          baseline_mean  mesh_mean      delta
# metric
# total_latency_s                 16.402     36.046     19.645
# total_prompt_tokens           1429.750  13114.600  11684.850
# total_completion_tokens        940.900   3205.300   2264.400
# error_rate                       0.000      0.000      0.000

# %%
fig = plot_phase_comparison(summary)
fig.show()
# Out:
# /var/folders/bt/24h30wdj22n3_7blzqcykkc00000gn/T/ipykernel_22309/2101383746.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plot_latency_distribution(mesh_df, label="Phase 2 Mesh")
fig.show()
# Out:
# /var/folders/bt/24h30wdj22n3_7blzqcykkc00000gn/T/ipykernel_22309/1233421362.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ## Observations
#
# > Fill this in after running both sweeps.
#
# - Phase 1 mean latency: X.Xs | Phase 2 mean latency: X.Xs
# - Delta: +X.Xs (+X%)
# - Phase 1 token cost: Xk | Phase 2 token cost: Xk
# - message_count (Phase 2): X per run
# - state_size_bytes (Phase 2): Xk bytes
#
# ## Notes for Phase 3
#
# > What failure modes are most concerning given these metrics?
