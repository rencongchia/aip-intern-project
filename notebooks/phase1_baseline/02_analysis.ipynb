# %% [markdown]
# # Phase 1 Baseline — Analysis

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path("../../")))

from analysis.aggregate import load_runs
from analysis.plots import plot_latency_distribution, plot_token_cost

df = load_runs("../../artifacts/", prefix="baseline")
print(f"Loaded {len(df)} baseline runs")
display(df.describe())
# Out:
# Loaded 20 baseline runs
#        total_latency_s  total_prompt_tokens  total_completion_tokens  \
# count        20.000000            20.000000                20.000000
# mean         16.401565          1429.750000               940.900000
# std           1.348069            26.803132                33.832249
# min          14.211104          1391.000000               891.000000
# 25%          15.325598          1411.750000               918.250000
# 50%          16.314862          1420.500000               936.000000
# 75%          17.440756          1454.250000               961.000000
# max          18.464489          1479.000000              1031.000000
#
#        step_trace_len
# count            20.0
# mean              3.0
# std               0.0
# min               3.0
# 25%               3.0
# 50%               3.0
# 75%               3.0
# max               3.0

# %%
fig = plot_latency_distribution(df, label="Phase 1 Baseline")
fig.show()
# Out:
# /var/folders/bt/24h30wdj22n3_7blzqcykkc00000gn/T/ipykernel_49830/686547081.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plot_token_cost(df, label="Phase 1 Baseline")
fig.show()
# Out:
# /var/folders/bt/24h30wdj22n3_7blzqcykkc00000gn/T/ipykernel_49830/4188267463.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ## Observations
#
# > Fill this in after running the sweep.
#
# - Mean latency: X.Xs (σ = X.Xs)
# - Mean token cost: Xk prompt + Xk completion
# - Error rate: X/20
# - Step trace always complete: yes/no
#
# ## Notes for Phase 2
#
# > What patterns or anomalies should the Phase 2 intern know about?
