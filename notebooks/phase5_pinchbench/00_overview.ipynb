# %% [markdown]
# # Phase 5: PinchBench Safety Scoring
#
# ## Scope
# Run PinchBench on OpenClaw and its variants, score each against the failure taxonomy rubric,
# and run the unguarded bulk-action task inside KiloClaw's sandbox to test whether it catches
# the failure or lets it through silently.
#
# ## Where to start
# 1. Obtain PinchBench, OpenClaw, and KiloClaw
# 2. Run PinchBench scenarios against OpenClaw variants
# 3. Score against failure taxonomy from Phase 3 rubric
# 4. Document findings in this notebook
#
# ## Handoff requirement
# Phase 6 cleans up the repo for reference. Ensure all Phase 5 results are committed.
