# %% [markdown]
# # Phase 3: Fault Injection
#
# ## Scope
# Inject four failures into the mesh: agent timeout mid-task, malformed JSON from a tool call,
# lost state checkpoint, context window overflow. Score each on recovery time, output quality,
# and whether recovery was automatic or manual.
#
# ## Where to start
# 1. Read `src/aip_intern/failures/injectors.py` — stub interfaces for each failure type
# 2. Read `src/aip_intern/failures/scoring.py` — RecoveryScore dataclass and scoring stubs
# 3. Implement the stubs, then run `01_run.ipynb`
#
# ## Handoff requirement
# Before handing off to Phase 4, document recovery scores in `01_run.ipynb` outputs.

# %%
# Verify stubs are importable
from aip_intern.failures.injectors import (
    inject_timeout, inject_malformed_json,
    inject_checkpoint_loss, inject_context_overflow
)
from aip_intern.failures.scoring import RecoveryScore, score_recovery
print("Stubs imported successfully — implement the bodies in failures/")
